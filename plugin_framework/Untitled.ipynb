# %%
from plugin_manager import PluginManager

plugin_manager = PluginManager()

# %%
# Buscar todos los plugins instalados
plugin_manager.load_plugins()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[2], line 2
#       1 # Buscar todos los plugins instalados
# ----> 2 plugin_manager.load_plugins()
#
# File /workspace/plugin_framework/plugin_manager.py:22, in PluginManager.load_plugins(self)
#      20 if not descriptor.exists():
#      21     continue
# ---> 22 self.load_plugin(folder)
#
# File /workspace/plugin_framework/plugin_manager.py:37, in PluginManager.load_plugin(self, folder)
#      30 module = importlib.import_module(
#      31     f"plugins.{folder.name}.{module_name}"
#      32 )
#      33 #module = importlib.import_module(info["module"])
#      34 #
#      35 #cls = getattr(module, info["class"])
# ---> 37 cls = getattr(module, class_name)
#      38 plugin = cls(info)
#      39 self.plugins[plugin.name] = plugin
#
# AttributeError: module 'plugins.UnetSegmentationPlugin.plugin' has no attribute 'UnetSegmentationPlugin'
