# %%
from api_stable.mammography import MammographyDicom
from encoder_service import MammographyEncoder

# %%
from pathlib import Path
import sys
import pandas as pd
import numpy as np

PROJECT_ROOT = Path.cwd()
if not (PROJECT_ROOT / 'api_stable').exists():
    PROJECT_ROOT = PROJECT_ROOT.parent

if str(PROJECT_ROOT) not in sys.path:
    sys.path.insert(0, str(PROJECT_ROOT))

# %%
DICOM_PATH = Path('/workspace/Data/NL-breast/abnormal/p_4333/left-c/CC/IM-0126-0002-0001.dcm')
if not DICOM_PATH.exists():
    raise FileNotFoundError(f'Actualiza DICOM_PATH: {DICOM_PATH}')

mammo = MammographyDicom.from_dicom(DICOM_PATH)
img = mammo.image.copy()

# %%
print(mammo.metadata)
# Out:
# patient=PatientInfo(patient_id='', age=65, sex='F') vendor=VendorInfo(manufacturer='GE MEDICAL SYSTEMS', model_name='Senographe Essential VERSION ADS_53.10.10') acquisition=AcquisitionInfo(kvp=29.0, exposure=50.0, exposure_time=805.0, tube_current=61.0, compression_force=100.0) breast=BreastInfo(laterality='L', view='CC', breast_implant_present=False) image=ImageInfo(rows=2294, columns=1914, bits_stored=12, pixel_spacing=None, photometric_interpretation='MONOCHROME2', presentation_lut_shape='IDENTITY', window_center=['2635', '2683', '2557'], window_width=['900', '750', '1050'], window_center_width_explanation=['NORMAL', 'HARDER', 'SOFTER'], voi_lut_function='SIGMOID')

# %%
encoder = MammographyEncoder.encode(mammo)

# %%
print(encoder)
import json
print(json.loads(encoder['metadata'])['view'])
# Out:
# {'data_path': '/tmp/1.2.826.0.1.3680043.8.498.78223124475573545728625076946705233496.nii.gz', 'metadata': '{"patient_id": "", "age": 65, "sex": "F", "manufacturer": "GE MEDICAL SYSTEMS", "model_name": "Senographe Essential VERSION ADS_53.10.10", "kvp": 29.0, "exposure": 50.0, "exposure_time": 805.0, "tube_current": 61.0, "compression_force": 100.0, "laterality": "L", "view": "CC", "breast_implant_present": false, "rows": 2294, "columns": 1914, "bits_stored": 12, "pixel_spacing": null, "photometric_interpretation": "MONOCHROME2", "presentation_lut_shape": "IDENTITY", "window_center": [2635.0, 2683.0, 2557.0], "window_width": [900.0, 750.0, 1050.0], "window_center_width_explanation": ["NORMAL", "HARDER", "SOFTER"], "voi_lut_function": "SIGMOID"}'}
# CC

# %%
from aip_platform import  AIPlatform

# %%
service = AIPlatform()
# Out:
# http://preprocessing-unet-segmentation:8002
# http://preprocessing-resnet-classification:8005
# http://preprocessing-explainability:8004
# http://preprocessing-gmic:8003

# %%
response = service.predict('GMIC',mammo)

print(response)
# Out:
# {'data_path': '/tmp/1.2.826.0.1.3680043.8.498.78223124475573545728625076946705233496.nii.gz', 'metadata': '{"patient_id": "", "age": 65, "sex": "F", "manufacturer": "GE MEDICAL SYSTEMS", "model_name": "Senographe Essential VERSION ADS_53.10.10", "kvp": 29.0, "exposure": 50.0, "exposure_time": 805.0, "tube_current": 61.0, "compression_force": 100.0, "laterality": "L", "view": "CC", "breast_implant_present": false, "rows": 2294, "columns": 1914, "bits_stored": 12, "pixel_spacing": null, "photometric_interpretation": "MONOCHROME2", "presentation_lut_shape": "IDENTITY", "window_center": [2635.0, 2683.0, 2557.0], "window_width": [900.0, 750.0, 1050.0], "window_center_width_explanation": ["NORMAL", "HARDER", "SOFTER"], "voi_lut_function": "SIGMOID"}'}
# {'status': 'ok', 'model_loaded': True}
# <Response [200]>
# {'algorithm': 'GMIC', 'version': '0.1', 'task': 'classification', 'results': '{"score": "0.01102189", "saliency_map": "/tmp/1197dab5-dd38-4a88-b94c-2df63cc8a7a4.nii.gz"}'}

# %%
import numpy as np
import matplotlib.pyplot as plt

plt.imshow(mammo.image.to_numpy(), cmap='gray')
plt.show()
