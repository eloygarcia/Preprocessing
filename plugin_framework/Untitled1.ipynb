# %%
from plugin_manager import PluginManager

# %%
from plugins.UnetSegmentationPlugin.predictor import Predictor
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 from plugins.UnetSegmentationPlugin.predictor import Predictor
#
# File /workspace/plugin_framework/plugins/UnetSegmentationPlugin/predictor.py:6
#       3 import torch
#       4 from abc import ABC, abstractmethod
# ----> 6 from model import Model
#       7 from preprocessing import Preprocessing
#       8 from postprocessing import Postprocessing
#
# ModuleNotFoundError: No module named 'model'

# %%
manager = PluginManager()

# %%
from plugins.UnetSegmentationPlugin.predictor import UnetPredictor
from plugins.ImageClassificationPlugin.predictor import ResNetPredictor
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 from plugins.UnetSegmentationPlugin.predictor import UnetPredictor
#       2 from plugins.ImageClassificationPlugin.predictor import ResNetPredictor
#
# File /workspace/plugin_framework/plugins/UnetSegmentationPlugin/predictor.py:6
#       3 import torch
#       4 from abc import ABC, abstractmethod
# ----> 6 from model import Model
#       7 from preprocessing import Preprocessing
#       8 from postprocessing import Postprocessing
#
# ModuleNotFoundError: No module named 'model'

# %%
manager.register('unet', UnetPredictor())
manager.register('resnet', ResNetPredictor())

# %%
print(manager.list_plugins())

# %%
for name in manager.list_plugins():
    predictor = manager.get_algorithm(name)
    print(
        predictor.get_metadata()
    )

# %%
from inference_service import InferenceService

# %%
service = InferenceService(manager)

# %%
import numpy as np

# %%
result = service.predict('Breast Segmentation', np.array(50))

# %%
request ={"algorithm":"unet", "data":np.array(50)}

# %%
result = service.predict(
    request["algorithm"],
    request["data"]
)

# %%
def fake_http_request(
    algorithm,
    image
):

    return service.predict(
        algorithm,
        image
    )

# %%
result = fake_http_request(
    "unet",
    image
)
